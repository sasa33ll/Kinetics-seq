# %%
import os
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.sparse as sp

# %%
adata_cancer = sc.read_h5ad('cancercell_kinetics_adata.h5ad')

# %%
plt.figure(figsize=(6, 3)) 
sc.pl.umap(adata_cancer, color='alpha', 
           cmap='RdBu_r', 
           vmax= 'p99',
           s =20,
           frameon=False,
           show=False)

# plt.savefig("Fig6_alpha_cancercell_umap.pdf", format='pdf', bbox_inches='tight', dpi=300)
# Out:
# <AxesSubplot: title={'center': 'alpha'}, xlabel='UMAP1', ylabel='UMAP2'>

# %%
sc.pp.normalize_total(adata_cancer, target_sum=1e4) 
sc.pp.log1p(adata_cancer)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Ppia', 
           cmap='RdBu_r', 
           s =20,ax=ax,
           frameon=False,
           show=False)
# plt.savefig("SI_Ppia_total.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Actb', 
           cmap='RdBu_r', 
           ax=ax,
           s =20,
           frameon=False,
           show=False)
# plt.savefig("SI_Actb_total.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Itgb1', 
           cmap='RdBu_r', 
           s =20,
           ax=ax,
           frameon=False,
           show=False)
# plt.savefig("SI_Itgb1_total.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Gpx3', 
           cmap='RdBu_r', 
           s =20,
           ax=ax,
           frameon=False,
           show=False)
# plt.savefig("SI_Gpx3_total.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Gpx3', 
           cmap='RdBu_r', 
           s =20,
           ax=ax,
           frameon=False,
           show=False)
# plt.savefig("SI_Gpx3_total.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Actb', 
           cmap='RdBu_r', 
           layer='alpha',
           vmax ='p99',
           s =20,
           ax=ax,
           frameon=False,
           show=False)
# plt.savefig("SI_Actb_alpha.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Itgb1', 
           cmap='RdBu_r', 
           layer='alpha',
           vmax ='p99',
           s =20,
           ax=ax,
           frameon=False,
           show=False)
# plt.savefig("SI_Itgb1_alpha.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Itgb1', 
           cmap='RdBu_r', 
           layer='gamma',
           vmax ='p99',
           s =20,
           ax=ax,
           frameon=False,
           show=False)
# plt.savefig("SI_Itgb1_gamma.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Actb', 
           cmap='RdBu_r', 
           layer='gamma',
           vmax ='p99',
           s =20,
           frameon=False,
           ax=ax,
           show=False)
# plt.savefig("SI_Actb_gamma.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Ppia', 
           cmap='RdBu_r', 
           layer='gamma',
           vmax ='p99',
           s =20,
           frameon=False,
           ax=ax,
           show=False)
# plt.savefig("SI_Ppia_gamma.pdf", format='pdf', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sc.pl.umap(adata_cancer, color='Gpx3', 
           cmap='RdBu_r', 
           layer='gamma',
           vmax ='p99',
           s =20,
           ax=ax,
           frameon=False,
           show=False)
# plt.savefig("SI_Gpx3_gamma.pdf", format='pdf', bbox_inches='tight', dpi=300)
